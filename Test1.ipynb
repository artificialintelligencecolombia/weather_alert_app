# %%
import requests

# %%
API_KEY = 'a31826faf7d1eaa3b356be645473c542'
latitude = 6.281630
longitude = 75.332850
endpoint = f'https://api.openweathermap.org/data/2.5/forecast?lat={latitude}&lon={longitude}&appid={API_KEY}'

# %%
response = requests.get(endpoint)
response.raise_for_status()
print(f"Response: {response}")
print(f"code: {response.status_code}")
# Out:
# Response: <Response [200]>
# code: 200

# %%
data = response.json()
print(data)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1735840800, 'main': {'temp': 300.82, 'feels_like': 303.79, 'temp_min': 300.82, 'temp_max': 300.99, 'pressure': 1012, 'sea_level': 1012, 'grnd_level': 1011, 'humidity': 75, 'temp_kf': -0.17}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 10.64, 'deg': 72, 'gust': 12.73}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-01-02 18:00:00'}, {'dt': 1735851600, 'main': {'temp': 300.71, 'feels_like': 303.68, 'temp_min': 300.7, 'temp_max': 300.71, 'pressure': 1010, 'sea_level': 1010, 'grnd_level': 1009, 'humidity': 76, 'temp_kf': 0.01}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 11.59, 'deg': 66, 'gust': 12.53}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-01-02 21:00:00'}, {'dt': 1735862400, 'main': {'temp': 300.54, 'feels_like': 302.99, 'temp_min': 300.54, 'temp_max': 300.54, 'pressure': 1009, 'sea_level': 1009, 'grnd_level': 1009, 'humidity': 73, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 11.99, 'deg': 58, 'gust': 13.27}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-01-03 00:00:00'}, {'dt': 1735873200, 'main': {'temp': 300.59, 'feels_like': 302.98, 'temp_min': 300.59, 'temp_max': 300.59, 'pressure': 1012, 'sea_level': 1012, 'grnd_level': 1012, 'humidity': 72, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 93}, 'wind': {'speed': 10.64, 'deg': 53, 'gust': 11.48}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-01-03 03:00:00'}, {'dt': 1735884000, 'main': {'temp': 300.5, 'feels_like': 303.02, 'temp_min': 300.5, 'temp_max': 300.5, 'pressure': 1012, 'sea_level': 1012, 'grnd_level': 1012, 'humidity': 74, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 96}, 'wind': {'speed': 10.54, 'deg': 64, 'gust': 11.02}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-01-03 06:00:00'}, {'dt': 1735894800, 'main': {'temp': 300.28, 'feels_like': 302.69, 'temp_min': 300.28, 'temp_max': 300.28, 'pressure': 1009, 'sea_level': 1009, 'grnd_level': 1009, 'humidity': 75, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 11.52, 'deg': 66, 'gust': 12.21}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-01-03 09:00:00'}, {'dt': 1735905600, 'main': {'temp': 300.35, 'feels_like': 302.83, 'temp_min': 300.35, 'temp_max': 300.35, 'pressure': 1009, 'sea_level': 1009, 'grnd_level': 1009, 'humidity': 75, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 11.62, 'deg': 70, 'gust': 12.06}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-01-03 12:00:00'}, {'dt': 1735916400, 'main': {'temp': 300.69, 'feels_like': 303.52, 'temp_min': 300.69, 'temp_max': 300.69, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 1011, 'humidity': 75, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 11.11, 'deg': 73, 'gust': 11.64}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-01-03 15:00:00'}, {'dt': 1735927200, 'main': {'temp': 300.74, 'feels_like': 303.87, 'temp_min': 300.74, 'temp_max': 300.74, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 1011, 'humidity': 77, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 11.01, 'deg': 75, 'gust': 11. ...
